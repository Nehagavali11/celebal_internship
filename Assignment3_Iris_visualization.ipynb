# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv("Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df = df.drop(columns = ['Id'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# no. of samples on each class
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [raw]
# Preprocessing Dataset

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [raw]
# EDA

# %% [raw]
# Histogram

# %%
df['SepalLengthCm'].hist(color = "pink", edgecolor = "hotpink")
plt.title('Histogram of Sepal Length (cm)')
plt.show()

# %%
df['SepalWidthCm'].hist(color = "red", edgecolor = "blue")
plt.title('Histogram of Sepal Width (cm)')
plt.show()

# %%
df['PetalLengthCm'].hist(color = "yellow", edgecolor = "black")
plt.title('Histogram of Petal Length (cm)')
plt.show()

# %%
df['PetalWidthCm'].hist(color = "cyan", edgecolor = "magenta")
plt.title('Histogram of Petal Width (cm)')
plt.show()

# %% [raw]
# Bar Chart

# %%
col = df.columns.tolist()
print(col)
# Out:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']

# %%
x = df['Species']
y = df['SepalLengthCm']
plt.bar(x,y,color = "hotpink",width = 0.5)
plt.title("Sepal Length by Iris Species")
plt.show()

# %%
x = df['Species']
y = df['SepalWidthCm']
plt.bar(x,y,color = "blue",width = 0.5)
plt.title("Sepal Width by Iris Species")
plt.show()

# %%
x = df['Species']
y = df['PetalLengthCm']
plt.bar(x,y,color = "red",width = 0.5)
plt.title("Petal Length by Iris Species")
plt.show()

# %%
x = df['Species']
y = df['PetalWidthCm']
plt.bar(x,y,color = "green",width = 0.5)
plt.title("Petal Width by Iris Species")
plt.show()

# %% [raw]
# Scatter Plot

# %%
# compare of sepal and petal width,len
x = df['SepalLengthCm']
y = df['SepalWidthCm']
plt.scatter(x,y,color = "green",marker = "+")

x = df['PetalLengthCm']
y = df['PetalWidthCm']
plt.scatter(x,y,color = "red",marker = ".")

plt.show()

# %%
x = df['PetalLengthCm']
y = df['SepalLengthCm']
colors = np.random.choice(['hotpink', 'yellow'], size=len(x))
plt.scatter(x, y, c=colors,s = 80,marker = "*")
plt.title('Scatter plot of Petal Length vs Sepal Length')
plt.show()

# %%
x = df['PetalWidthCm']
y = df['SepalWidthCm']
colors = np.random.choice(['gray', 'cyan'], size=len(x))
plt.scatter(x, y, c=colors)
plt.title('Scatter plot of Petal Width vs Sepal Width')
plt.show()

# %% [raw]
# Pie Chart

# %%
# Count the occurrences of each species
species_counts = df['Species'].value_counts()
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%')
plt.show()

# %% [raw]
# Correlation Matrix

# %%
# Calculate the correlation matrix for the relevant numerical features
features = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
corr_matrix = df[features].corr()

print(corr_matrix)

# Plot the heatmap for better visualization
sns.heatmap(corr_matrix, annot=True, cmap='cividis')
plt.title('Correlation Matrix of Iris Features')
plt.show()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000
